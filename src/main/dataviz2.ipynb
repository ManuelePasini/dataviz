# %% [markdown]
# # Ph.D. Course - Data Vizualization
# #### Authors
# -  Manuele Pasini - manuele.pasini@unibo.it
# - Gianni Tumedei - gianni.tumedei2@unibo.it

# %%
import pandas as pd
import os
import numpy as np

input_path = os.path.join(os.sep, "home", "dataset")
output_path = os.path.join(os.sep, "home", "preprocess_results")

# %% [markdown]
# #### Preprocessing

# %%
devices = pd.read_csv(os.path.join(input_path, 'devices.csv'))
measurements = pd.read_csv(os.path.join(input_path, 'measurements.csv'))

measurements["deveui"] = measurements["deveui"].str.replace("-", "").str.upper()
measurements = measurements.drop(columns=["acceleration_x", "acceleration_y", "acceleration_z"])
measurements = measurements.rename(columns={"deveui": "device_id"})

devices = devices.rename(columns={"id": "device_id", "location/0": "latitude", "location/1": "longitude"})
devices = devices.drop(columns=["type", "status", "installed", "addedBy"])


# Merge the two dataframes on the 'device_id' columncd
merged_df = pd.merge(devices, measurements, on='device_id')

# Convert the 'location' column to a (lon,lat) format
#merged_df["location"] = merged_df.apply(lambda row: f"{row['location/0']}, {row['location/1']}", axis=1)
#merged_df = merged_df.drop(columns=["location/0", "location/1"])

# Convert the 'timestamp' column to datetime format
merged_df["time"] = pd.to_datetime(merged_df["time"], unit='ms')
merged_df["time"] = merged_df["time"].dt.strftime('%Y-%m-%d %H:%M:%S')

# Remove columns with more than 60% missing values
missing_threshold = 0.6
cleaned_df = merged_df.loc[:, merged_df.isnull().mean() < missing_threshold]

merged_df.to_csv(os.path.join(output_path, 'merged_data.csv'), index=False)

# %% [markdown]
# ### Dataset overview

# %%
print(f"Number of devices: {merged_df["device_id"].unique().size}")
print(f"Number of distinct devices {merged_df["desc"].unique().size}")

print(f"Number of measurements: {merged_df.size}")
print(f"Measurements time window: from {merged_df["time"].min()} to {merged_df["time"].max()}")

merged_df
# Out:
# Number of devices: 429
# Number of distinct devices 358
# Number of measurements: 98437616
# Measurements time window: from 2020-08-01 00:00:02 to 2021-02-23 20:32:28
#                 device_id  floor                                   desc  \
# 0        A81758FFFE046433      4  Attached to old video projector mount
# 1        A81758FFFE046433      4  Attached to old video projector mount
# 2        A81758FFFE046433      4  Attached to old video projector mount
# 3        A81758FFFE046433      4  Attached to old video projector mount
# 4        A81758FFFE046433      4  Attached to old video projector mount
# ...                   ...    ...                                    ...
# 6152346  A81758FFFE030FFE      1                  Hallway next to LO105
# 6152347  A81758FFFE030FFE      1                  Hallway next to LO105
# 6152348  A81758FFFE030FFE      1                  Hallway next to LO105
# 6152349  A81758FFFE030FFE      1                  Hallway next to LO105
# 6152350  A81758FFFE030FFE      1                  Hallway next to LO105
#
#          latitude  longitude                 time  temperature  humidity  \
# 0        65.05765   25.46897  2020-08-01 00:01:10         23.6      39.0
# 1        65.05765   25.46897  2020-08-01 00:05:11         23.7      39.0
# 2        65.05765   25.46897  2020-08-01 00:09:10         23.6      39.0
# 3        65.05765   25.46897  2020-08-01 00:13:11         23.7      39.0
# 4        65.05765   25.46897  2020-08-01 00:17:11         23.6      39.0
# ...           ...        ...                  ...          ...       ...
# 6152346  65.05809   25.46576  2021-02-23 19:29:38         21.8       7.0
# 6152347  65.05809   25.46576  2021-02-23 19:44:38         21.9       7.0
# 6152348  65.05809   25.46576  2021-02-23 19:59:38         21.8       7.0
# 6152349  65.05809   25.46576  2021-02-23 20:14:38         21.8       7.0
# 6152350  65.05809   25.46576  2021-02-23 20:29:38         21.8       7.0
#
#          light  motion    co2  battery  sound_avg  sound_peak  moisture  \
# 0          2.0    20.0    NaN    3.641       34.0        64.0       NaN
# 1          2.0    21.0    NaN    3.638       34.0        64.0       NaN
# 2          2.0    21.0    NaN    3.638       34.0        64.0       NaN
# 3          2.0    22.0    NaN    3.641       34.0        64.0       NaN
# 4          2.0    18.0    NaN    3.641       34.0        64.0       NaN
# ...        ...     ...    ...      ...        ...         ...       ...
# 6152346   41.0     2.0  635.0    3.689        NaN         NaN       NaN
# 6152347    3.0     0.0  640.0    3.686        NaN         NaN       NaN
# 6152348    3.0     0.0  636.0    3.689        NaN         NaN       NaN
# 6152349    3.0     0.0  637.0    3.686        NaN         NaN       NaN
# 6152350    3.0     0.0  636.0    3.686        NaN         NaN       NaN
#
#          pressure
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 6152346       NaN
# 6152347       NaN
# 6152348       NaN
# 6152349       NaN
# 6152350       NaN
#
# [6152351 rows x 16 columns]

# %% [markdown]
# #### Filter, format, and group data for the first visualization

# %%
def clean_dataset(df, groupby_column, focus_column):
    filtered_df = df.copy()
    filtered_df["time"] = pd.to_datetime(filtered_df["time"], errors="coerce").dt.tz_localize("UTC", ambiguous="NaT")

    # Define the date ranges to exclude
    start_date = pd.Timestamp("2020-09-01T00:00:00Z")
    end_date = pd.Timestamp("2021-05-10T23:59:59Z")
    filtered_df = filtered_df[(filtered_df["time"] >= start_date) & (filtered_df["time"] <= end_date)]

    exclusion_ranges = [
        (pd.Timestamp("2020-10-12T00:00:00Z"), pd.Timestamp("2020-10-18T23:59:59Z")), # Autumn break (Syysloma) week 42
        (pd.Timestamp("2020-12-21T00:00:00Z"), pd.Timestamp("2021-01-06T23:59:59Z")), # Christmas break
        (pd.Timestamp("2020-03-08T00:00:00Z"), pd.Timestamp("2020-03-14T23:59:59Z"))  # Winter break week 10
    ]
    # Apply filters
    for start, end in exclusion_ranges:
        filtered_df = filtered_df[~((filtered_df["time"] >= start) & (filtered_df["time"] <= end))]

    # Remove weekends
    filtered_df = filtered_df[filtered_df["time"].dt.weekday < 5]
    # Only keep floor 1
    filtered_df = filtered_df[filtered_df["floor"] == 1]
    # Only keep rows with motion and sound values
    filtered_df = filtered_df.dropna(subset=[groupby_column, focus_column])
    # Remove outliers
    outliers = ["A81758FFFE046462", "A81758FFFE04652A", "A81758FFFE046572"]
    filtered_df = filtered_df[~filtered_df["device_id"].isin(outliers)]

    if focus_column == "sound_avg":
        # Add linearized sound because plotting logarithmic values is useless
        filtered_df["sound_avg_linear"] = 10 ** (filtered_df["sound_avg"] / 20)
        filtered_df["sound_peak_linear"] = 10 ** (filtered_df["sound_peak"] / 20)

    filtered_df.to_csv(os.path.join(output_path, "filtered_data.csv"), index=False)
    return filtered_df

filtered_df = clean_dataset(merged_df, "motion", "sound_avg")

# %%
filtered_df["hour"] = filtered_df["time"].dt.hour

# Group by "device_id" and "hour"
grouped_df = filtered_df.groupby(["device_id", "hour"]).agg(
    floor=("floor", "first"),
    desc=("desc", "first"),
    temperature=("temperature", "mean"),
    humidity=("humidity", "mean"),
    light=("light", "mean"),
    motion=("motion", "mean"),
    co2=("co2", "mean"),
    battery=("battery", "mean"),
    sound_avg=("sound_avg", "mean"),
    sound_peak=("sound_peak", "mean"),
    sound_avg_linear=("sound_avg_linear", "mean"),
    sound_peak_linear=("sound_peak_linear", "mean"),
    moisture=("moisture", "mean"),
    pressure=("pressure", "mean"),
    latitude=("latitude", "first"),
    longitude=("longitude", "first"),
).reset_index()

grouped_df.to_csv(os.path.join(output_path, 'grouped_data.csv'), index=False)

grouped_df
# Out:
#              device_id  hour  floor                      desc  temperature  \
# 0     A81758FFFE046337     0      1  In the middle of Kastari    21.276147
# 1     A81758FFFE046337     1      1  In the middle of Kastari    21.269706
# 2     A81758FFFE046337     2      1  In the middle of Kastari    21.056587
# 3     A81758FFFE046337     3      1  In the middle of Kastari    20.535000
# 4     A81758FFFE046337     4      1  In the middle of Kastari    20.091691
# ...                ...   ...    ...                       ...          ...
# 2155  A81758FFFE046583    19      1                        L7    20.184150
# 2156  A81758FFFE046583    20      1                        L7    20.156627
# 2157  A81758FFFE046583    21      1                        L7    20.121662
# 2158  A81758FFFE046583    22      1                        L7    20.076900
# 2159  A81758FFFE046583    23      1                        L7    20.066361
#
#        humidity      light     motion  co2   battery  sound_avg  sound_peak  \
# 0     27.865443   0.000000  83.623853  NaN  3.635217  49.660550   64.000000
# 1     27.385294   0.000000  83.855882  NaN  3.635129  49.591176   64.002941
# 2     27.404192   0.362275  83.523952  NaN  3.635237  49.988024   66.287425
# 3     27.447059   1.629412  83.170588  NaN  3.635059  50.800000   70.438235
# 4     26.922636   2.644699  83.808023  NaN  3.634731  51.297994   72.074499
# ...         ...        ...        ...  ...       ...        ...         ...
# 2155  27.775216  26.841499  78.968300  NaN  3.627666  34.253602   64.510086
# 2156  27.927711  25.262048  79.006024  NaN  3.627735  34.114458   64.096386
# 2157  27.875371  26.243323  79.103858  NaN  3.627837  34.103858   64.080119
# 2158  27.784195  25.680851  79.313070  NaN  3.627681  34.173252   64.036474
# 2159  27.853211  25.868502  79.333333  NaN  3.627768  34.143731   64.103976
#
#       sound_avg_linear  sound_peak_linear  moisture  pressure  latitude  \
# 0           308.469821        1584.893192       NaN       NaN  65.05702
# 1           307.293440        1585.461975       NaN       NaN  65.05702
# 2           328.101785        3208.544770       NaN       NaN  65.05702
# 3           361.421157        5521.481641       NaN       NaN  65.05702
# 4           386.405504        6097.472105       NaN       NaN  65.05702
# ...                ...                ...       ...       ...       ...
# 2155         53.240307        2027.585352       NaN       NaN  65.05990
# 2156         50.861932        1614.259575       NaN       NaN  65.05990
# 2157         50.794251        1611.848977       NaN       NaN  65.05990
# 2158         51.328041        1599.253923       NaN       NaN  65.05990
# 2159         51.090067        1624.042184       NaN       NaN  65.05990
#
#       longitude
# 0      25.46767
# 1      25.46767
# 2      25.46767
# 3      25.46767
# 4      25.46767
# ...         ...
# 2155   25.46602
# 2156   25.46602
# 2157   25.46602
# 2158   25.46602
# 2159   25.46602
#
# [2160 rows x 18 columns]

# %% [markdown]
# ### More overview

# %% [markdown]
# ### Visualization 1 - Manuele Pasini

# %%
groupby = "motion"
value = "co2"
filtered_df = clean_dataset(merged_df, groupby, value)

# %%
filtered_df
# Out:
#                 device_id  floor                   desc  latitude  longitude  \
# 60487    A81758FFFE030F6A      1          Tellus Cube 6  65.05875   25.46565
# 60488    A81758FFFE030F6A      1          Tellus Cube 6  65.05875   25.46565
# 60489    A81758FFFE030F6A      1          Tellus Cube 6  65.05875   25.46565
# 60490    A81758FFFE030F6A      1          Tellus Cube 6  65.05875   25.46565
# 60491    A81758FFFE030F6A      1          Tellus Cube 6  65.05875   25.46565
# ...                   ...    ...                    ...       ...        ...
# 6152346  A81758FFFE030FFE      1  Hallway next to LO105  65.05809   25.46576
# 6152347  A81758FFFE030FFE      1  Hallway next to LO105  65.05809   25.46576
# 6152348  A81758FFFE030FFE      1  Hallway next to LO105  65.05809   25.46576
# 6152349  A81758FFFE030FFE      1  Hallway next to LO105  65.05809   25.46576
# 6152350  A81758FFFE030FFE      1  Hallway next to LO105  65.05809   25.46576
#
#                              time  temperature  humidity  light  motion  \
# 60487   2020-09-01 00:01:28+00:00         21.5      43.0    6.0     0.0
# 60488   2020-09-01 00:31:28+00:00         21.4      43.0    6.0     0.0
# 60489   2020-09-01 00:46:28+00:00         21.3      43.0    6.0     0.0
# 60490   2020-09-01 01:01:28+00:00         21.4      43.0    6.0     0.0
# 60491   2020-09-01 01:16:28+00:00         21.3      43.0    6.0     0.0
# ...                           ...          ...       ...    ...     ...
# 6152346 2021-02-23 19:29:38+00:00         21.8       7.0   41.0     2.0
# 6152347 2021-02-23 19:44:38+00:00         21.9       7.0    3.0     0.0
# 6152348 2021-02-23 19:59:38+00:00         21.8       7.0    3.0     0.0
# 6152349 2021-02-23 20:14:38+00:00         21.8       7.0    3.0     0.0
# 6152350 2021-02-23 20:29:38+00:00         21.8       7.0    3.0     0.0
#
#            co2  battery  sound_avg  sound_peak  moisture  pressure
# 60487    388.0    3.698        NaN         NaN       NaN       NaN
# 60488    389.0    3.698        NaN         NaN       NaN       NaN
# 60489    389.0    3.698        NaN         NaN       NaN       NaN
# 60490    398.0    3.698        NaN         NaN       NaN       NaN
# 60491    394.0    3.698        NaN         NaN       NaN       NaN
# ...        ...      ...        ...         ...       ...       ...
# 6152346  635.0    3.689        NaN         NaN       NaN       NaN
# 6152347  640.0    3.686        NaN         NaN       NaN       NaN
# 6152348  636.0    3.689        NaN         NaN       NaN       NaN
# 6152349  637.0    3.686        NaN         NaN       NaN       NaN
# 6152350  636.0    3.686        NaN         NaN       NaN       NaN
#
# [1561945 rows x 16 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

restroom_co2_devices = {
    "North Restroom": [
        "A81758FFFE030FB5",
        "A81758FFFE046576",
        "A81758FFFE031089",
    ],
    "Central Restroom": {
        "A81758FFFE030F7B",
        "A81758FFFE030F5A",
        "A81758FFFE031055"
    },
    "South Restroom": {
        "A81758FFFE031029",
        "A81758FFFE030F70",
    },
    "Outdoor Restroom": [
        "A81758FFFE031051",
        "A81758FFFE03102C",
        "A81758FFFE031005"
    ]
}

device_to_restroom = {
    device: restroom
    for restroom, devices in restroom_co2_devices.items()
    for device in devices
}

co2_devices = list(device_to_restroom.keys())
filtered_df = filtered_df.loc[filtered_df["device_id"].isin(co2_devices)]
filtered_df["restroom"] = filtered_df["device_id"].map(device_to_restroom)

idx_min = filtered_df.groupby('device_id')[groupby].idxmin().dropna()
idx_max = filtered_df.groupby('device_id')[groupby].idxmax().dropna()

df_min = filtered_df.loc[idx_min].copy()
df_min['motion_type'] = 'min'

df_max = filtered_df.loc[idx_max].copy()
df_max['motion_type'] = 'max'

result = pd.concat([df_min, df_max])
result['restroom'] = result['device_id'].map(device_to_restroom)

pivot = result.pivot(index='device_id', columns='motion_type', values="co2")
pivot = pivot.loc[pivot["min"] < pivot["max"]]
pivot['restroom'] = pivot.index.map(device_to_restroom)

pivot_grouped = pivot.groupby('restroom')[['min', 'max']].mean()
pivot_grouped = pivot_grouped.sort_values(by='max', ascending=False)

def plot_grouped(pivot_grouped, cap_value=1300, log=False):
    x = np.arange(len(pivot_grouped))
    width = 0.35

    co2_min = pivot_grouped['min'].clip(upper=cap_value)
    co2_max = pivot_grouped['max'].clip(upper=cap_value)

    fig, ax = plt.subplots(figsize=(10, 6))
    ax.bar(x - width/2, co2_min, width, label='Min crowded')
    ax.bar(x + width/2, co2_max, width, label='Max crowded')

    for i, val in enumerate(pivot_grouped['min']):
        if val > cap_value:
            ax.text(x[i] - width/2, cap_value, f'{val:.0f}', ha='center', va='bottom', fontsize=9, color='blue')
    for i, val in enumerate(pivot_grouped['max']):
        if val > cap_value:
            ax.text(x[i] + width/2, cap_value, f'{val:.0f}', ha='center', va='bottom', fontsize=9, color='darkorange')

    ax.set_xlabel('Restroom')
    ax.set_ylabel('CO2 (ppm)')
    title = f'Difference in CO2 values within restroom during most and least crowded times'
    if log:
        ax.set_yscale('log')
    ax.set_title(title)
    ax.set_xticks(x)
    ax.set_xticklabels(pivot_grouped.index, rotation=15)
    ax.legend()
    ax.set_ylim(1, cap_value + 20 if not log else cap_value*2)

    plt.tight_layout()
    plt.savefig(os.path.join(output_path, f'co2_plot_{log}.png'), dpi=300)
    plt.show()


# 8. Esegui i plot
plot_grouped(pivot_grouped, cap_value=1100, log=False)
plot_grouped(pivot_grouped, cap_value=1100, log=True)

# %% [markdown]
# ### Visualization 1 - Gianni Tumedei

# %%
result
# Out:
# Empty DataFrame
# Columns: [device_id, floor, desc, latitude, longitude, time, temperature, humidity, light, motion, co2, battery, sound_avg, sound_peak, moisture, pressure, restroom, motion_type]
# Index: []
